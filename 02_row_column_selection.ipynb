# %% [markdown]
# # Row and Column Selection with Pandas
#
# ## Objective
# This notebook demonstrates different techniques for selecting rows and columns in a pandas DataFrame, including label-based indexing, positional indexing, and boolean filtering.

# %%
person = {
    "first": "Kenan",
    "last":"Kurt",
    "email":"kenantkurt@gmail.com"
}

# %%
people = {
    "first": ["Kenan"],
    "last": [" Kurt"],
    "email": ["kenantkurt@gmail.com"]
}

# %%
people = {
    "first":["Kenan","Ahmet","Sercem","Huseyin"],
    "last": ["Kurt","Aycan","Makum","Dincer"],
    "email":["kenantkurt@gmail.com","aa@gmail.com","sm@gmail.com","hd@gmail.com"]
}
people
# Out:
# {'first': ['Kenan', 'Ahmet', 'Sercem', 'Huseyin'],
#  'last': ['Kurt', 'Aycan', 'Makum', 'Dincer'],
#  'email': ['kenantkurt@gmail.com',
#   'aa@gmail.com',
#   'sm@gmail.com',
#   'hd@gmail.com']}

# %%
people["email"]
# Out:
# ['kenantkurt@gmail.com', 'aa@gmail.com', 'sm@gmail.com', 'hd@gmail.com']

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#      first    last                 email
# 0    Kenan    Kurt  kenantkurt@gmail.com
# 1    Ahmet   Aycan          aa@gmail.com
# 2   Sercem   Makum          sm@gmail.com
# 3  Huseyin  Dincer          hd@gmail.com

# %%
df["first"]
# Out:
# 0      Kenan
# 1      Ahmet
# 2     Sercem
# 3    Huseyin
# Name: first, dtype: str

# %%
type(df)
# it has more than 1 dimension.
# Out:
# pandas.DataFrame

# %%
type(df["first"])
# here it has just one dimension.
# Out:
# pandas.Series

# %%
df.first
# Out:
# 0      Kenan
# 1      Ahmet
# 2     Sercem
# 3    Huseyin
# Name: first, dtype: str

# %%
df["first"]
# Out:
# 0      Kenan
# 1      Ahmet
# 2     Sercem
# 3    Huseyin
# Name: first, dtype: str

# %%
df[["last","email"]]
# Out:
#      last                 email
# 0    Kurt  kenantkurt@gmail.com
# 1   Aycan          aa@gmail.com
# 2   Makum          sm@gmail.com
# 3  Dincer          hd@gmail.com

# %%
type(df.columns)
# Out:
# pandas.Index

# %%
print(df)
# Out:
#      first    last                 email
# 0    Kenan    Kurt  kenantkurt@gmail.com
# 1    Ahmet   Aycan          aa@gmail.com
# 2   Sercem   Makum          sm@gmail.com
# 3  Huseyin  Dincer          hd@gmail.com

# %%
df.iloc[0]
# Out:
# first                   Kenan
# last                     Kurt
# email    kenantkurt@gmail.com
# Name: 0, dtype: str

# %%
df.iloc[[0,3]]
# Out:
#      first    last                 email
# 0    Kenan    Kurt  kenantkurt@gmail.com
# 3  Huseyin  Dincer          hd@gmail.com

# %%
df.iloc[0,1]
# Out:
# 'Kurt'

# %%
df.iloc[[0,1],2]
# Out:
# 0    kenantkurt@gmail.com
# 1            aa@gmail.com
# Name: email, dtype: str

# %%
df.loc[[0,1],["email"]]
type(df.loc[[0,1],["email"]])
# Out:
# pandas.DataFrame

# %%
df.loc[[0,1], "email"]
type(df.loc[[0,1], "email"])
# Out:
# pandas.Series

# %%
df.loc[[0,1],["email","last"]]
# Out:
#                   email   last
# 0  kenantkurt@gmail.com   Kurt
# 1          aa@gmail.com  Aycan

# %%
import pandas as pd
df = pd.read_csv('/Users/kenantufankurt/Desktop/PYTHON/PANDAS/COREY SCHAFER/stack-overflow-developer-survey-2019/survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
pd.read_csv('/Users/kenantufankurt/Desktop/PYTHON/PANDAS/COREY SCHAFER/stack-overflow-developer-survey-2019/survey_results_schema.csv')
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
df.shape
# Out:
# (88883, 85)

# %%
df["Hobbyist"]
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: str

# %%
df["Hobbyist"].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df["OpenSourcer"].value_counts()
# Out:
# OpenSourcer
# Never                                                 32295
# Less than once per year                               24972
# Less than once a month but more than once per year    20561
# Once a month or more often                            11055
# Name: count, dtype: int64

# %%
df.loc[0]
# Out:
# Respondent                                                      1
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 0, Length: 85, dtype: object

# %%
df.iloc[[1,2,3]]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
#
#                OpenSourcer                                         OpenSource  \
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
# 3                    Never  The quality of OSS and closed source software ...
#
#                            Employment                 Country         Student  \
# 1  Not employed, but looking for work  Bosnia and Herzegovina  Yes, full-time
# 2                  Employed full-time                Thailand              No
# 3                  Employed full-time           United States              No
#
# ...

# %%
df.iloc[[0,1], 2]
# Out:
# 0    Yes
# 1     No
# Name: Hobbyist, dtype: str

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.loc[0]
# Out:
# Respondent                                                      1
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 0, Length: 85, dtype: object

# %%
df.loc[[0,1], ["email","last"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df.loc[[0,1], ["email","last"]]
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# -> 1386     return self._getitem_lowerdim(tup)
# ...

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df["Hobbyist"]
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: str

# %%
df["Hobbyist"].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df.loc[0, "Hobbyist"]
# Out:
# 'Yes'

# %%
df.loc[[0,1,2],["Hobbyist"]]
# Out:
#   Hobbyist
# 0      Yes
# 1       No
# 2      Yes

# %%
df.loc[0:2, ["Hobbyist"]]
# Out:
#   Hobbyist
# 0      Yes
# 1       No
# 2      Yes

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc[0:2, "Hobbyist":"Employment"]
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time
